# %% [markdown]
# # **DATA UNDERSTANDING**

# %% [markdown]
# Dataset ini diambil dari https://www.kaggle.com/datasets/bhadramohit/mental-health-dataset

# %% [markdown]
# Mengimpor Library Pandas

# %%
import pandas as pd

# %% [markdown]
# Mengimpor dataset dan menampilkannya

# %%
df = pd.read_csv("/content/mental_health_dataset.csv")

df
# Out:
#      User_ID  Age             Gender  Occupation    Country  \
# 0          1   36         Non-binary       Sales     Canada
# 1          2   34             Female   Education         UK
# 2          3   65         Non-binary       Sales        USA
# 3          4   34               Male       Other  Australia
# 4          5   22             Female  Healthcare     Canada
# ..       ...  ...                ...         ...        ...
# 995      996   46         Non-binary       Other    Germany
# 996      997   31               Male       Sales     Canada
# 997      998   33             Female          IT    Germany
# 998      999   42             Female     Finance  Australia
# 999     1000   43  Prefer not to say       Sales    Germany
#
#     Mental_Health_Condition Severity Consultation_History Stress_Level  \
# 0                        No   Medium                  Yes       Medium
# 1                       Yes      NaN                   No          Low
# ...

# %% [markdown]
# **MEMERIKSA STRUKTUR DATA**

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   User_ID                  1000 non-null   int64
#  1   Age                      1000 non-null   int64
#  2   Gender                   1000 non-null   object
#  3   Occupation               1000 non-null   object
#  4   Country                  1000 non-null   object
#  5   Mental_Health_Condition  1000 non-null   object
#  6   Severity                 499 non-null    object
#  7   Consultation_History     1000 non-null   object
#  8   Stress_Level             1000 non-null   object
#  9   Sleep_Hours              1000 non-null   float64
#  10  Work_Hours               1000 non-null   int64
#  11  Physical_Activity_Hours  1000 non-null   int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 93.9+ KB
# None

# %% [markdown]
# **MEMERIKSA TIPE DATA**

# %%
print(df.dtypes)
# Out:
# User_ID                      int64
# Age                          int64
# Gender                      object
# Occupation                  object
# Country                     object
# Mental_Health_Condition     object
# Severity                    object
# Consultation_History        object
# Stress_Level                object
# Sleep_Hours                float64
# Work_Hours                   int64
# Physical_Activity_Hours      int64
# dtype: object

# %% [markdown]
# **MEMERIKSA JUMLAH KOLOM DAN BARIS**

# %%
print(df.count)
# Out:
# <bound method DataFrame.count of      User_ID  Age             Gender  Occupation    Country  \
# 0          1   36         Non-binary       Sales     Canada
# 1          2   34             Female   Education         UK
# 2          3   65         Non-binary       Sales        USA
# 3          4   34               Male       Other  Australia
# 4          5   22             Female  Healthcare     Canada
# ..       ...  ...                ...         ...        ...
# 995      996   46         Non-binary       Other    Germany
# 996      997   31               Male       Sales     Canada
# 997      998   33             Female          IT    Germany
# 998      999   42             Female     Finance  Australia
# 999     1000   43  Prefer not to say       Sales    Germany
#
#     Mental_Health_Condition Severity Consultation_History Stress_Level  \
# 0                        No   Medium                  Yes       Medium
# ...

# %% [markdown]
# **MEMERIKSA STATISTIK DESKRIPTIF**

# %%
print(df.describe())
# Out:
#            User_ID         Age  Sleep_Hours   Work_Hours  \
# count  1000.000000  1000.00000  1000.000000  1000.000000
# mean    500.500000    41.89200     7.095600    54.621000
# std     288.819436    13.97475     1.713861    14.709035
# min       1.000000    18.00000     4.000000    30.000000
# 25%     250.750000    30.00000     5.600000    42.000000
# 50%     500.500000    42.00000     7.100000    55.000000
# 75%     750.250000    54.00000     8.500000    67.000000
# max    1000.000000    65.00000    10.000000    80.000000
#
#        Physical_Activity_Hours
# count              1000.000000
# mean                  5.134000
# std                   3.081808
# min                   0.000000
# 25%                   3.000000
# 50%                   5.000000
# 75%                   8.000000
# max                  10.000000

# %% [markdown]
# **ANALISIS KORELASI**

# %%
print(df.corr(numeric_only=True))
# Out:
#                           User_ID       Age  Sleep_Hours  Work_Hours  \
# User_ID                  1.000000 -0.022400     0.057434    0.000734
# Age                     -0.022400  1.000000    -0.043114   -0.013825
# Sleep_Hours              0.057434 -0.043114     1.000000   -0.005550
# Work_Hours               0.000734 -0.013825    -0.005550    1.000000
# Physical_Activity_Hours  0.008222  0.052679    -0.015012    0.039258
#
#                          Physical_Activity_Hours
# User_ID                                 0.008222
# Age                                     0.052679
# Sleep_Hours                            -0.015012
# Work_Hours                              0.039258
# Physical_Activity_Hours                 1.000000

# %% [markdown]
# # **PERSIAPAN DATA**

# %% [markdown]
# Dataset ini diambil dari https://www.kaggle.com/datasets/bhadramohit/mental-health-dataset

# %% [markdown]
# **MENCARI MISSING VALUES**

# %%
(df.isna().sum()/len(df))*100
# Out:
# User_ID                     0.0
# Age                         0.0
# Gender                      0.0
# Occupation                  0.0
# Country                     0.0
# Mental_Health_Condition     0.0
# Severity                   50.1
# Consultation_History        0.0
# Stress_Level                0.0
# Sleep_Hours                 0.0
# Work_Hours                  0.0
# Physical_Activity_Hours     0.0
# dtype: float64

# %%
df[df['Severity'].isnull()]
# Out:
#      User_ID  Age      Gender   Occupation    Country Mental_Health_Condition  \
# 1          2   34      Female    Education         UK                     Yes
# 8          9   25        Male    Education        USA                     Yes
# 9         10   65  Non-binary   Healthcare      India                      No
# 10        11   52      Female        Other      India                      No
# 11        12   23        Male  Engineering     Canada                     Yes
# ..       ...  ...         ...          ...        ...                     ...
# 989      990   49      Female      Finance        USA                      No
# 994      995   56  Non-binary      Finance     Canada                     Yes
# 995      996   46  Non-binary        Other    Germany                      No
# 996      997   31        Male        Sales     Canada                      No
# 998      999   42      Female      Finance  Australia                     Yes
#
# ...

# %% [markdown]
# **PENANGANAN MISSING VALUES**

# %%
df['Severity'].dropna().describe()
# Out:
# count     499
# unique      3
# top       Low
# freq      176
# Name: Severity, dtype: object

# %%
kolom_1 = 'Severity'

modus_kolom = df[kolom_1].mode()[0]
df[kolom_1] = df[kolom_1].fillna(modus_kolom)

# %%
print(df.tail())
print(df[kolom_1].isnull().sum())
# Out:
#      User_ID  Age             Gender Occupation    Country  \
# 995      996   46         Non-binary      Other    Germany
# 996      997   31               Male      Sales     Canada
# 997      998   33             Female         IT    Germany
# 998      999   42             Female    Finance  Australia
# 999     1000   43  Prefer not to say      Sales    Germany
#
#     Mental_Health_Condition Severity Consultation_History Stress_Level  \
# 995                      No      Low                  Yes          Low
# 996                      No      Low                   No         High
# 997                      No     High                  Yes       Medium
# 998                     Yes      Low                   No       Medium
# 999                      No      Low                  Yes          Low
#
#      Sleep_Hours  Work_Hours  Physical_Activity_Hours
# 995          9.3          50                        0
# 996          4.5          37                        6
# ...

# %% [markdown]
# **MENCARI DATA DUPLIKAT**

# %%
df
# Out:
#      User_ID  Age             Gender  Occupation    Country  \
# 0          1   36         Non-binary       Sales     Canada
# 1          2   34             Female   Education         UK
# 2          3   65         Non-binary       Sales        USA
# 3          4   34               Male       Other  Australia
# 4          5   22             Female  Healthcare     Canada
# ..       ...  ...                ...         ...        ...
# 995      996   46         Non-binary       Other    Germany
# 996      997   31               Male       Sales     Canada
# 997      998   33             Female          IT    Germany
# 998      999   42             Female     Finance  Australia
# 999     1000   43  Prefer not to say       Sales    Germany
#
#     Mental_Health_Condition Severity Consultation_History Stress_Level  \
# 0                        No   Medium                  Yes       Medium
# 1                       Yes      Low                   No          Low
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [User_ID, Age, Gender, Occupation, Country, Mental_Health_Condition, Severity, Consultation_History, Stress_Level, Sleep_Hours, Work_Hours, Physical_Activity_Hours]
# Index: []

# %% [markdown]
# Tidak ada Kolom dalam dataset yang terindikasi duplikat.

# %% [markdown]
# **MENCARI OUTLIERS**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                    Persentase Outliers
# User_ID                                  0.0
# Age                                      0.0
# Sleep_Hours                              0.0
# Work_Hours                               0.0
# Physical_Activity_Hours                  0.0

# %% [markdown]
# Tidak ada Nilai outliers yang terindikasi didalam dataset.

# %% [markdown]
# **Kontruksi Data**

# %%
def anxiety_level(row):
    if row['Stress_Level'] == 'High' or row['Severity'] == 'High' or row['Sleep_Hours'] < 5:
        return 'High'
    elif row['Stress_Level'] == 'Medium' or row['Severity'] == 'Medium' or (5 <= row['Sleep_Hours'] <= 6):
        return 'Medium'
    else:
        return 'Low'

df['Anxiety_Level'] = df.apply(anxiety_level, axis=1)
df
# Out:
#      User_ID  Age             Gender  Occupation    Country  \
# 0          1   36         Non-binary       Sales     Canada
# 1          2   34             Female   Education         UK
# 2          3   65         Non-binary       Sales        USA
# 3          4   34               Male       Other  Australia
# 4          5   22             Female  Healthcare     Canada
# ..       ...  ...                ...         ...        ...
# 995      996   46         Non-binary       Other    Germany
# 996      997   31               Male       Sales     Canada
# 997      998   33             Female          IT    Germany
# 998      999   42             Female     Finance  Australia
# 999     1000   43  Prefer not to say       Sales    Germany
#
#     Mental_Health_Condition Severity Consultation_History Stress_Level  \
# 0                        No   Medium                  Yes       Medium
# 1                       Yes      Low                   No          Low
# ...

# %% [markdown]
# Mengkontruksi Baris Anxiety_Level dengan menggunakan baris Stress_Level, Severity, atau Sleep_Hours.

# %% [markdown]
# **Reduksi Data**

# %%
df = df.drop('Country', axis=1)

# %%
df
# Out:
#      User_ID  Age             Gender  Occupation Mental_Health_Condition  \
# 0          1   36         Non-binary       Sales                      No
# 1          2   34             Female   Education                     Yes
# 2          3   65         Non-binary       Sales                     Yes
# 3          4   34               Male       Other                      No
# 4          5   22             Female  Healthcare                     Yes
# ..       ...  ...                ...         ...                     ...
# 995      996   46         Non-binary       Other                      No
# 996      997   31               Male       Sales                      No
# 997      998   33             Female          IT                      No
# 998      999   42             Female     Finance                     Yes
# 999     1000   43  Prefer not to say       Sales                      No
#
#     Severity Consultation_History Stress_Level  Sleep_Hours  Work_Hours  \
# ...

# %% [markdown]
# Mereduksi baris Country karena kurang relevan.
